# %%
import csv
import pandas as pd
from pathlib import Path

BASE_DIR = Path.cwd().parents[2]
DATA_DIR = BASE_DIR / "Football-Match-Prediction-Project-FIFA-World-Cup-2026"/ "data"
training_dataset = DATA_DIR / "processed" / "training_dataset.csv"

training_dataset.exists()
#df = pd.read_csv()
# Out:
# True

# %%
df = pd.read_csv(training_dataset)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49433 entries, 0 to 49432
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       49433 non-null  str
#  1   home_team                  49433 non-null  str
#  2   away_team                  49433 non-null  str
#  3   home_recent_wins           49433 non-null  int64
#  4   home_recent_draws          49433 non-null  int64
#  5   home_recent_losses         49433 non-null  int64
#  6   home_recent_goals_for      49433 non-null  int64
#  7   home_recent_goals_against  49433 non-null  int64
#  8   home_recent_goal_diff      49433 non-null  int64
#  9   away_recent_wins           49433 non-null  int64
#  10  away_recent_draws          49433 non-null  int64
#  11  away_recent_losses         49433 non-null  int64
#  12  away_recent_goals_for      49433 non-null  int64
#  13  away_recent_goals_against  49433 non-null  int64
# ...
